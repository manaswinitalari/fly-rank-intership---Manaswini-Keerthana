# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
One row represents one observed entity record for one time period in the selected data slice.
I use March 2026 as the development month. The time window is from March 1, 2026 to March 31, 2026.
March is used because it is a mid-panel month and not the final outcome month. T
he query below checks whether the selected entity and time key is unique.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
Features: I will use a maximum of five fields that describe historical activity and performance. These features will use only information available at the decision moment.

Label or proxy: The label is the selected outcome or performance measure that the model will predict or rank. The label will not be included in the final honest feature set.

Context: The month, date, entity identifier, source information, and availability status will be used for filtering, validation, and interpretation.

Excluded: I will exclude future information, direct outcome fields, and fields that are not available at the decision moment. These fields are excluded because they may reveal the target and cause data leakage. Private names, URLs, and private queries are also excluded.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
The queries below verify the data contract for the March 2026 data slice.
The first query checks the grain by looking for duplicate entity and time combinations.
 The second query measures the number of rows and the observed date range.
  The third query checks availability using IS TRUE and shows the number of rows that remain available.

# %%
The feature frame contains a maximum of five features.

Feature 1: Historical activity measure. It is knowable at the decision moment because it is calculated using observations available before or on the decision date.

Feature 2: Historical performance measure. It is knowable at the decision moment because it uses only measured values from the available observation period.

Feature 3: Recent activity measure. It is knowable at the decision moment because it is based only on records observed up to the decision date.

Feature 4: Entity historical measure. It is knowable at the decision moment because it is calculated from the entity’s previously observed history.

Feature 5: Availability or coverage measure. It is knowable at the decision moment because it is determined using data already present in the warehouse.

The label is not included in the honest five-feature frame.

# %%
I intentionally added one label-derived column to the feature set and trained a quick model.
The score increased because the added column contained information that directly revealed or closely represented the outcome.
 This result was not a valid measure of model performance.
I then removed the label-derived column and ran the evaluation again.
The score became lower but more realistic. This is the honest score because the remaining features contain only information that is available at the decision moment.
 The leaked column was removed from the final feature frame.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
This data shows observed and measured patterns, but it cannot prove why an outcome occurred or establish a causal relationship. The observation history may be unbalanced because some entities may have more records than others. Earlier records may contain only Search Console information, so data availability and feature meaning may differ across time. Overlapping time windows may also make nearby observations dependent.

The results should be treated as directional and decision-support information based on the available warehouse data. They should not be treated as complete evidence of user behavior or causal effects.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
